# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from praxis.YoloPointingTransformer import TransformerPointingTrainer
from omegaconf import DictConfig, OmegaConf
from torch.utils.data import DataLoader, WeightedRandomSampler, Subset
import dataset
from pathlib import Path
import logging
import torch
import dataset
import os
from pathlib import Path

# %%
def setup_dataloader(cfg: DictConfig) -> DataLoader:

    DEVICE = cfg.DEVICE
    if DEVICE == "cpu" and cfg.task == "train":
        logging.warning("Training DeePoint with CPU takes a long time.")
    if cfg.task == "test" and cfg.verbose is not True and cfg.shrink_rate != 1:
        logging.warning(
            "Using only part of test dataset. You should set `shrink_rate=1` except for speeding up the performance for visualization"
        )

    assert not (
        cfg.task == "test" and cfg.ckpt is None
    ), "checkpoint should be specified for evaluation"
    
    keypoints_path = Path(os.getcwd()).parent.parent / cfg.keypoints_root
    train_ds = dataset.DPDataset(keypoints_path, cfg)
    
    train_dl = DataLoader(
        train_ds,
        batch_size=cfg.hardware.bs,
        #sampler=train_sampler,
        num_workers=cfg.hardware.nworkers,
        persistent_workers=True if cfg.hardware.nworkers != 0 else False,
    )
    
    return train_dl

# %%
def main_func():
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    cfg = OmegaConf.load("../conf/pcmodel.yaml")
    cfg.DEVICE = DEVICE
    dl = setup_dataloader(cfg)
    print(cfg)

# %%
main_func()
# Out:
# WARNING:root:Training DeePoint with CPU takes a long time.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 main_func()
#
# Cell In[61], line 5, in main_func()
#       3 cfg = OmegaConf.load("../conf/pcmodel.yaml")
#       4 cfg.DEVICE = DEVICE
# ----> 5 dl = setup_dataloader(cfg)
#       6 print(cfg)
#
# Cell In[60], line 16, in setup_dataloader(cfg)
#      11 assert not (
#      12     cfg.task == "test" and cfg.ckpt is None
#      13 ), "checkpoint should be specified for evaluation"
#      15 keypoints_path = Path(os.getcwd()).parent.parent / cfg.keypoints_root
# ---> 16 train_ds = dataset.DPDataset(keypoints_path, cfg)
#      18 train_dl = DataLoader(
#      19     train_ds,
#      20     batch_size=cfg.hardware.bs,
#    (...)
#      23     persistent_workers=True if cfg.hardware.nworkers != 0 else False,
#      24 )
#      26 return train_dl
#
# File ~/Documents/GitHub/deepoint/src/dataset.py:238, in DPDataset.__init__(self, keypoints_path, cfg, omit_image)
#     236 self.action_class_dict = {0: [-1], 1: list(range(0, 100))}
#     237 self.num_classes = len(self.action_class_dict)
# --> 238 with (keypoints_path / "triangulation.pickle").open("rb") as f:
#     239     self.coords = pickle.load(f)
#     240 with (keypoints_path / "collected_json.pickle").open("rb") as f:
#
# File /usr/local/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pathlib.py:1044, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1042 if "b" not in mode:
#    1043     encoding = io.text_encoding(encoding)
# -> 1044 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/davidtung/Documents/GitHub/data/keypoints/triangulation.pickle'
